# %% [markdown]
# # TUTORIAL 1: DATA FORMAT CONVERSION
#
# ## The IIDM format
#
# When navigating through the files of the dataset, one will find that the format of each snapshot file is **.xiidm**. This format corresponds to an XML export of an IIDM (iTesla Internal Data Model), which is the format used in the **PyPowSyBl** framework. However, users may want to export the grid models to work with a different program. This tutorial will show how to export the grid models to convert from the IIDM to the supported formats and vice versa. Note that some conversions are still unidirectional, as some parsers are not yet developed.
#
# **Import (from \* to IIDM):** Importing a file is opening it from a given format (\*) and 'translating' it to the framework format, in this case, the IIDM format.
#
# **Export (from IIDM to *):** Conversely, exporting a file is writing it in a given format (*) after 'translating' it from the framework format.
#
# To this date, the supported import and export formats in **PyPowSyBl** are the following:
#
# | Format | Description | Import | Export | Supported Extensions |
# |--------|-------------|----------|--------| ------- |
# | **PSS/E** | Format for Siemens PSS®E software** | <span style="color: green;">YES | <span style="color: green;">YES | raw, rawx |
# | **CIM-CGMES** | Standard format for European grid data exchange | <span style="color: green;">YES | <span style="color: green;">YES | xml |
# | **IIDM (XIIDM, JIIDM, BIIDM)** | Internal Data Model in XML, JSON, and binary format respectively | <span style="color: green;">YES | <span style="color: green;">YES | xiidm, iidm, json, jiidm, biidm, bin, xml |
# | **UCTE-DEF** | Legacy format for European grid data exchange | <span style="color: green;">YES |  <span style="color: red;">NO* | uct, txt |
# | **PowerFactory** | Format for DigSILENT PowerFactory software | <span style="color: green;">YES |  <span style="color: red;">NO | dgs |
# | **IEEE-CDF** | IEEE standard format | <span style="color: green;">YES |  <span style="color: red;">NO | - |
# | **Matpower** | Format for the free and open-source Matlab toolbox | <span style="color: green;">YES | <span style="color: green;">YES | mat |
# | **AMPL** | Data separated value format to parse with AMPL |  <span style="color: red;">NO | <span style="color: green;">YES | txt |
#
#
# \* Grid models can be exported to UCTE-DEF format only if it was initially loaded from an UCTE-DEF format.
#
# ## Supported import or export formats
#
#
# To check which formats are supported, as well as the supported extensions for importing, you can run the following code:

# %%
import pypowsybl as pp
import pandas as pd


pd.set_option('display.max_colwidth', None)   # show full contents of every column
pd.set_option('display.width', None)          # don’t line‑wrap rows
pd.set_option('display.max_columns', None)

print(pp.network.get_import_formats())
print(pp.network.get_import_supported_extensions())
# Out:
# ['BIIDM', 'CGMES', 'IEEE-CDF', 'JIIDM', 'MATPOWER', 'POWER-FACTORY', 'PSS/E', 'UCTE', 'XIIDM']
# ['RAW', 'RAWX', 'UCT', 'biidm', 'bin', 'dgs', 'iidm', 'jiidm', 'json', 'mat', 'raw', 'rawx', 'txt', 'uct', 'xiidm', 'xml']

# %%
print(pp.network.get_export_formats())
# Out:
# ['AMPL', 'BIIDM', 'CGMES', 'JIIDM', 'MATPOWER', 'PSS/E', 'UCTE', 'XIIDM']

# %% [markdown]
# ## Export a file
#
# The process of exporting is pretty similar to the one described for importing. We can directly save by just inputing the folder we want to save, or the name of the file we want to create:

# %%
pp_grid = pp.network.load('data/initial_snapshot.xiidm.bz2')
pp_grid.save('CGMES_model_1', format='AMPL')

# %% [markdown]
# Or we can check which parameters can be tweaked and select new values:

# %%
pp.network.get_export_parameters(fmt='CGMES')
# Out:
#                                                                                                                                                                                           description  \
# name
# iidm.export.cgmes.base-name                                                                                                                                                 Basename for output files
# iidm.export.cgmes.cim-version                                                                                                                                                   CIM version to export
# iidm.export.cgmes.export-boundary-power-flows                                                                                                                          Export boundaries' power flows
# iidm.export.cgmes.export-power-flows-for-switches                                                                                                                     Export power flows for switches
# iidm.export.cgmes.naming-strategy                                                                                                                     Configure what type of naming strategy you want
# iidm.export.cgmes.profiles                                                                                                                                                         Profiles to export
# iidm.export.cgmes.cgm_export                                                                                                                           True for a CGM export, False for an IGM export
# iidm.export.cgmes.boundary-EQ-identifier                                                                                                                                 Boundary EQ model identifier
# iidm.export.cgmes.boundary-TP-identifier                                                                                                                                 Boundary TP model identifier
# iidm.export.cgmes.modeling-authority-set                                                                                                                                       Modeling authority set
# iidm.export.cgmes.model-description                                                                                                                                                 Model description
# iidm.export.cgmes.export-transformers-with-highest-voltage-at-end1                                                                                   Export transformers with highest voltage at end1
# iidm.export.cgmes.sourcing-actor                                                                                                                     Sourcing actor name (for CGM business processes)
# iidm.export.cgmes.export-load-flow-status                                                                                                              Export load flow status of topological islands
# iidm.export.cgmes.max-p-mismatch-converged                                            Max mismatch in active power to consider a bus converged when exporting load flow status of topological islands
# iidm.export.cgmes.max-q-mismatch-converged                                          Max mismatch in reactive power to consider a bus converged when exporting load flow status of topological islands
# iidm.export.cgmes.export-sv-injections-for-slacks                                                                                                Export SvInjections with the mismatch of slack buses
# iidm.export.cgmes.uuid-namespace                                                                                      Namespace to use for name-based UUID generation. It must be a valid UUID itself
# iidm.export.cgmes.model-version                                                                                                                                                         Model version
# iidm.export.cgmes.business-process                                                                                                                                                   Business process
# iidm.export.cgmes.update-dependencies                               True if dependencies should be updated automatically. False if the user has already put them in the extension for metadata models
#
#                                                                            type  \
# name
# iidm.export.cgmes.base-name                                              STRING
# iidm.export.cgmes.cim-version                                            STRING
# iidm.export.cgmes.export-boundary-power-flows                           BOOLEAN
# iidm.export.cgmes.export-power-flows-for-switches                       BOOLEAN
# iidm.export.cgmes.naming-strategy                                        STRING
# iidm.export.cgmes.profiles                                          STRING_LIST
# iidm.export.cgmes.cgm_export                                            BOOLEAN
# iidm.export.cgmes.boundary-EQ-identifier                                 STRING
# iidm.export.cgmes.boundary-TP-identifier                                 STRING
# iidm.export.cgmes.modeling-authority-set                                 STRING
# iidm.export.cgmes.model-description                                      STRING
# iidm.export.cgmes.export-transformers-with-highest-voltage-at-end1      BOOLEAN
# iidm.export.cgmes.sourcing-actor                                         STRING
# iidm.export.cgmes.export-load-flow-status                               BOOLEAN
# iidm.export.cgmes.max-p-mismatch-converged                               DOUBLE
# iidm.export.cgmes.max-q-mismatch-converged                               DOUBLE
# iidm.export.cgmes.export-sv-injections-for-slacks                       BOOLEAN
# iidm.export.cgmes.uuid-namespace                                         STRING
# iidm.export.cgmes.model-version                                          STRING
# iidm.export.cgmes.business-process                                       STRING
# iidm.export.cgmes.update-dependencies                                   BOOLEAN
#
#                                                                                                  default  \
# name
# iidm.export.cgmes.base-name
# iidm.export.cgmes.cim-version
# iidm.export.cgmes.export-boundary-power-flows                                                       true
# iidm.export.cgmes.export-power-flows-for-switches                                                   true
# iidm.export.cgmes.naming-strategy                                                               identity
# iidm.export.cgmes.profiles                                                             [EQ, TP, SSH, SV]
# iidm.export.cgmes.cgm_export                                                                       false
# iidm.export.cgmes.boundary-EQ-identifier
# iidm.export.cgmes.boundary-TP-identifier
# iidm.export.cgmes.modeling-authority-set
# iidm.export.cgmes.model-description
# iidm.export.cgmes.export-transformers-with-highest-voltage-at-end1                                 false
# iidm.export.cgmes.sourcing-actor
# iidm.export.cgmes.export-load-flow-status                                                           true
# iidm.export.cgmes.max-p-mismatch-converged                                                           0.1
# iidm.export.cgmes.max-q-mismatch-converged                                                           0.1
# iidm.export.cgmes.export-sv-injections-for-slacks                                                   true
# iidm.export.cgmes.uuid-namespace                                    551699a3-6423-5ea2-9c3c-6b0b7fa8d731
# iidm.export.cgmes.model-version
# iidm.export.cgmes.business-process                                                                    1D
# iidm.export.cgmes.update-dependencies                                                               true
#
#                                                                       possible_values
# name
# iidm.export.cgmes.base-name
# iidm.export.cgmes.cim-version                                               [16, 100]
# iidm.export.cgmes.export-boundary-power-flows
# iidm.export.cgmes.export-power-flows-for-switches
# iidm.export.cgmes.naming-strategy
# iidm.export.cgmes.profiles                                          [EQ, TP, SSH, SV]
# iidm.export.cgmes.cgm_export
# iidm.export.cgmes.boundary-EQ-identifier
# iidm.export.cgmes.boundary-TP-identifier
# iidm.export.cgmes.modeling-authority-set
# iidm.export.cgmes.model-description
# iidm.export.cgmes.export-transformers-with-highest-voltage-at-end1
# iidm.export.cgmes.sourcing-actor
# iidm.export.cgmes.export-load-flow-status
# iidm.export.cgmes.max-p-mismatch-converged
# iidm.export.cgmes.max-q-mismatch-converged
# iidm.export.cgmes.export-sv-injections-for-slacks
# iidm.export.cgmes.uuid-namespace
# iidm.export.cgmes.model-version
# iidm.export.cgmes.business-process
# iidm.export.cgmes.update-dependencies

# %%
# For instance, we choose to only produce the EQ profiles.
pp_grid.save('CGMES_model_2', format='CGMES', parameters={'iidm.export.cgmes.profiles':'EQ'})

# %% [markdown]
# ## Import a file
#
# ### Default method
#
# The direct method to load a file of one of the supported formats is a straight-forward call to the load function:

# %%
# Example of a PSS/E model
grid_model = pp.network.load('data/psse_grid.raw')

# To display the full network diagram instead of a given selection, we can get the list of all the voltage level indexes uysing pandas DataFrame techinques
vl_ids = grid_model.get_voltage_levels().index.tolist()
diagram = grid_model.get_network_area_diagram(voltage_level_ids=vl_ids)
diagram

# %% [markdown]
# ### Custom method
#
# Depending on the format, we might want to tweak slightly some parameters of the parser. We can check first which are the options allowed for each format, aswell as its possible values, and then changing the desired parameter.

# %%
pp.network.get_import_parameters(fmt='PSS/E')
# Out:
#                                                                                                             description  \
# name
# psse.import.ignore-base-voltage                                               Ignore base voltage specified in the file
# psse.import.ignore-node-breaker-topology  Ignore the node breaker topology specified in the substation data of the file
#
#                                              type default possible_values
# name
# psse.import.ignore-base-voltage           BOOLEAN   false
# psse.import.ignore-node-breaker-topology  BOOLEAN   false

# %%
psse_grid = pp.network.load(file='data/psse_grid.raw', parameters={'psse.import.ignore-base-voltage': 'true'})

# To display the full network diagram instead of a given selection, we can get the list of all the voltage level indexes using pandas DataFrame techinques
vl_ids = psse_grid.get_voltage_levels().index.tolist()
diagram = psse_grid.get_network_area_diagram(voltage_level_ids=vl_ids)
diagram

# %% [markdown]
# We can see the effect of tweaking one of the input options. In this dummy example we have lost relevant information by removing the base voltage of all the elements.
